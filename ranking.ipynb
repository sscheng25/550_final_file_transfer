# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
import tweepy as tw
import textblob
import datetime

# %%
api_key = "ITD9Yb7phWqPOFno383BmXQgA"
api_key_secret = "PVcztaVsnvNp823X7BJg28iHI5jnMkgQLLc32hElO7UHRttzAM"
access_token = "1445914997373161479-hkiYPTq842GUwQxUtJ4BSPFWXVNC75"
access_token_secret = "haCCKeAZUqKBC2RuMWdJoKifbkv57AgCZNLVkfDZycydT"

# %%
auth = tw.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)


api = tw.API(auth, wait_on_rate_limit=True)

# %%
Parks = [
    "Great Smoky Mountains National Park",
    "Grand Canyon National Park",
    "Yosemite National Park",
    "Rocky Mountain National Park",
    "Yellowstone National Park",
    "Acadia National Park",
    "Olympic National Park",
    "Grand Teton National Park",
    "Shenandoah National Park",
    "Zion National Park",
    "Glacier National Park",
    "Mount Rainier National Park",
    "Hot Springs National Park",
    "Mammoth Cave National Park",
    "Hawai'i Volcanoes National Park",
    "Cuyahoga Valley National Park",
    "Badlands National Park",
    "Sequoia National Park",
    "Joshua Tree National Park",
    "Everglades National Park",
    "Petrified Forest National Park",
    "Kings Canyon National Park",
    "Haleakala National Park",
    "Bryce Canyon National Park",
    "Death Valley National Park",
    "Carlsbad Caverns National Park",
    "Wind Cave National Park",
    "Crater Lake National Park",
    "Saguaro National Park",
    "Mesa Verde National Park",
    "Arches National Park",
    "Theodore Roosevelt National Park",
    "Lassen Volcanic National Park",
    "Virgin Islands National Park",
    "Capitol Reef National Park",
    "Wolf Trap National Park for the Performing Arts",
    "Redwood National Park",
    "Biscayne National Park",
    "Denali National Park",
    "Denali National Preserve",
    "Big Bend National Park",
    "North Cascades National Park",
    "Canyonlands National Park",
    "Black Canyon of the Gunnison National Park",
    "Great Sand Dunes National Park",
    "Channel Islands National Park",
    "Glacier Bay National Park",
    "Pinnacles National Park",
    "Voyageurs National Park",
    "Guadalupe Mountains National Park",
    "Kenai Fjords National Park",
    "Great Basin National Park",
    "Congaree National Park",
    "Dry Tortugas National Park",
    "Wrangell-St. Elias National Park",
    "Katmai National Park",
    "Isle Royale National Park",
    "Lake Clark National Park",
    "Gates of the Arctic National Park",
    "Kobuk Valley National Park",
    "National Park of American Samoa",
]

# %%
search_words = [
    "#greatsmokymountainsnationalpark -filter:retweets",
    "#grandcanyonnationalpark -filter:retweets",
    "#yosemitenationalpark -filter:retweets",
    "#rockymountainnationalpark -filter:retweets",
    "#yellowstonenationalpark -filter:retweets",
    "#acadianationalpark -filter:retweets",
    "#olympicnationalpark -filter:retweets",
    "#grandtetonnationalpark -filter:retweets",
    "#shenandoahnationalpark -filter:retweets",
    "#zionnationalpark -filter:retweets",
    "#glaciernationalpark -filter:retweets",
    "#mountrainiernationalpark -filter:retweets",
    "#hotspringsnationalpark -filter:retweets",
    "#mammothcavenationalpark -filter:retweets",
    "#hawaiivolcanoesnationalpark -filter:retweets",
    "#cuyahogavalleynationalpark -filter:retweets",
    "#badlandsnationalpark -filter:retweets",
    "#sequoianationalpark -filter:retweets",
    "#joshuatreenationalpark -filter:retweets",
    "#evergladesnationalpark -filter:retweets",
    "#petrifiedforestnationalpark -filter:retweets",
    "#kingscanyonnationalpark -filter:retweets",
    "#haleakalanationalpark -filter:retweets",
    "#brycecanyonnationalpark -filter:retweets",
    "#deathvalleynationalpark -filter:retweets",
    "#carlsbadcavernsnationalpark -filter:retweets",
    "#windcavenationalpark -filter:retweets",
    "#craterlakenationalpark -filter:retweets",
    "#saguaronationalpark -filter:retweets",
    "#mesaverdenationalpark -filter:retweets",
    "#archesnationalpark -filter:retweets",
    "#theodorerooseveltnationalpark -filter:retweets",
    "#lassenvolcanicnationalpark -filter:retweets",
    "#virginislandsnationalpark -filter:retweets",
    "#capitolreefnationalpark -filter:retweets",
    "#wolftrapnationalparkfortheperformingarts -filter:retweets",
    "#redwoodnationalpark -filter:retweets",
    "#biscaynenationalpark -filter:retweets",
    "#denalinationalpark -filter:retweets",
    "#denalinationalpreserve -filter:retweets",
    "#bigbendnationalpark -filter:retweets",
    "#northcascadesnationalpark -filter:retweets",
    "#canyonlandsnationalpark -filter:retweets",
    "#blackcanyonofthegunnisonnationalpark -filter:retweets",
    "#greatsanddunesnationalpark -filter:retweets",
    "#channelislandsnationalpark -filter:retweets",
    "#glacierbaynationalpark -filter:retweets",
    "#pinnaclesnationalpark -filter:retweets",
    "#voyageursnationalpark -filter:retweets",
    "#guadalupemountainsnationalpark -filter:retweets",
    "#kenaifjordsnationalpark -filter:retweets",
    "#greatbasinnationalpark -filter:retweets",
    "#congareenationalpark -filter:retweets",
    "#drytortugasnationalpark -filter:retweets",
    "#wrangellsteliasnationalpark -filter:retweets",
    "#katmainationalpark -filter:retweets",
    "#isleroyalenationalpark -filter:retweets",
    "#lakeclarknationalpark -filter:retweets",
    "#gatesofthearcticnationalpark -filter:retweets",
    "#kobukvalleynationalpark -filter:retweets",
    "#nationalparkofamericansamoa -filter:retweets",
]

# %%
def remove_url(txt):
    """
    Replace URLs found in a text string with nothing 
    (i.e. it will remove the URL from the string).

    Parameters
    ----------
    txt : string
        A text string that you want to parse and remove urls.

    Returns
    -------
    The same txt string with url's removed.
    """
    import re
    return " ".join(re.sub("https://t.co/[A-Za-z\\d]+|&amp", "", txt).split())

# %%
def get_polarity(ls):
    polarity = {}
    polarity['park'] = search_words
    polarity['polarity'] = 0
    polarity = pd.DataFrame(polarity)
    p = polarity['polarity'].values.astype("float64")
    for i in range(len(polarity)):
        cursor = tw.Cursor(api.search,
                   q=polarity["park"][i],
                   lang="en",
                   tweet_mode='extended')
        tweets = [tweet for tweet in cursor.items(1000)]
        blobs = [textblob.TextBlob(remove_url(t.full_text)) for t in tweets]
        data = {}
        data['date'] = [tweet.created_at for tweet in tweets]
        data['polarity'] = [blob.sentiment.polarity for blob in blobs]
        data['subjectivity'] = [blob.sentiment.subjectivity for blob in blobs]
        data['text'] = [remove_url(tweet.full_text) for tweet in tweets]
        data = pd.DataFrame(data)
        zero = (data['polarity']==0).sum()
        print("number of unbiased tweets = ", zero)
        biased = data.loc[ data['polarity'] != 0 ].copy()
        print("number of biased tweets = ", len(biased))
        p[i] = biased['polarity'].mean()
    polarity['polarity'] = p
    
    return polarity

# %%
polarity = get_polarity(search_words)
# Out:
# number of unbiased tweets =  1
# number of biased tweets =  3
# number of unbiased tweets =  2
# number of biased tweets =  16
# number of unbiased tweets =  15
# number of biased tweets =  27
# number of unbiased tweets =  15
# number of biased tweets =  10
# number of unbiased tweets =  32
# number of biased tweets =  29
# number of unbiased tweets =  12
# number of biased tweets =  8
# number of unbiased tweets =  11
# number of biased tweets =  7
# number of unbiased tweets =  1
# number of biased tweets =  4
# number of unbiased tweets =  6
# number of biased tweets =  3
# number of unbiased tweets =  16
# number of biased tweets =  20
# number of unbiased tweets =  26
# number of biased tweets =  19
# number of unbiased tweets =  0
# number of biased tweets =  4
# number of unbiased tweets =  1
# number of biased tweets =  4
# number of unbiased tweets =  0
# number of biased tweets =  0
# number of unbiased tweets =  3
# number of biased tweets =  1
# ...

# %%
polarity["park"] = Parks

# %%
polarity.sort_values(by="polarity" , ascending=False).head(10)
# Out:
#                               park  polarity
# 55            Katmai National Park  1.000000
# 36           Redwood National Park  1.000000
# 28           Saguaro National Park  1.000000
# 27       Crater Lake National Park  1.000000
# 20  Petrified Forest National Park  1.000000
# 29        Mesa Verde National Park  0.816667
# 45   Channel Islands National Park  0.800000
# 19        Everglades National Park  0.755729
# 44  Great Sand Dunes National Park  0.700000
# 56       Isle Royale National Park  0.700000

# %%
polarity.head(30)
# Out:
#                                    park  polarity
# 0   Great Smoky Mountains National Park  0.412500
# 1            Grand Canyon National Park  0.351042
# 2                Yosemite National Park  0.330135
# 3          Rocky Mountain National Park  0.349750
# 4             Yellowstone National Park  0.295131
# 5                  Acadia National Park  0.271958
# 6                 Olympic National Park  0.486640
# 7             Grand Teton National Park  0.349545
# 8              Shenandoah National Park  0.633333
# 9                    Zion National Park  0.396904
# 10                Glacier National Park  0.169441
# 11          Mount Rainier National Park  0.277778
# 12            Hot Springs National Park  0.539062
# 13           Mammoth Cave National Park       NaN
# 14      Hawai'i Volcanoes National Park -0.100000
# 15        Cuyahoga Valley National Park  0.562500
# 16               Badlands National Park  0.256818
# 17                Sequoia National Park  0.218373
# ...

# %%
visitors = pd.read_csv("E:/graduate/musa550/assignment/final_data/Normalized_10_year_visitors.csv")

# %%
rank = pd.merge(polarity, visitors,left_on="park", right_on="ParkName")
rank = rank.drop(['ParkName'], axis=1)

# %%
rank["score"] = 0.5 * rank["polarity"] + 0.5 * rank["Normalized"]

# %%
rank.sort_values(by="score" , ascending=False)["park"].head(10)
# Out:
# 0     Great Smoky Mountains National Park
# 28                  Saguaro National Park
# 20         Petrified Forest National Park
# 27              Crater Lake National Park
# 36                  Redwood National Park
# 55                   Katmai National Park
# 29               Mesa Verde National Park
# 19               Everglades National Park
# 1              Grand Canyon National Park
# 45          Channel Islands National Park
# Name: park, dtype: object
