# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
# 61 National Parks data with visitations
NationalPark = pd.read_csv("C:/Users/CSS/Desktop/NationalParks.csv")
NationalPark
# Out:
#       State Unit Code                             Unit Name  \
# 0        NC      BLRI                    Blue Ridge Parkway
# 1        CA      GOGA  Golden Gate National Recreation Area
# 2        NC      GRSM   Great Smoky Mountains National Park
# 3        MS      NATR                 Natchez Trace Parkway
# 4        NV      LAKE    Lake Mead National Recreation Area
# ...     ...       ...                                   ...
# 21555    WY      YELL             Yellowstone National Park
# 21556    SD      WICA               Wind Cave National Park
# 21557    OR      CRLA             Crater Lake National Park
# 21558    CA      KICA            Kings Canyon National Park
# 21559    WA      MORA           Mount Rainier National Park
#
#                       Unit Type      Visitors  YearRaw
# 0                       Parkway   871,922,828    Total
# 1      National Recreation Area   611,031,225    Total
# 2                 National Park   521,947,058    Total
# ...

# %%
NationalPark = NationalPark[NationalPark['Unit Type'] == 'National Park']
NationalPark = NationalPark[NationalPark['YearRaw'] == 'Total']
NationalPark
# Out:
#     State Unit Code                            Unit Name      Unit Type  \
# 2      NC      GRSM  Great Smoky Mountains National Park  National Park
# 11     AZ      GRCA           Grand Canyon National Park  National Park
# 13     CA      YOSE               Yosemite National Park  National Park
# 15     CO      ROMO         Rocky Mountain National Park  National Park
# 16     WY      YELL            Yellowstone National Park  National Park
# ..    ...       ...                                  ...            ...
# 304    MI      ISRO            Isle Royale National Park  National Park
# 341    AK      LACL             Lake Clark National Park  National Park
# 348    AK      GAAR    Gates of the Arctic National Park  National Park
# 358    AK      KOVA           Kobuk Valley National Park  National Park
# 363    AS      NPSA      National Park of American Samoa  National Park
#
#          Visitors  YearRaw
# 2     521,947,058    Total
# 11    205,486,894    Total
# ...

# %%
# 62 National Parks data with geometry
NP_geo = gpd.read_file("C:/Users/CSS/Desktop/nps_boundary/nps_boundary.shp")
NP_geo.head()
# Out:
#   UNIT_CODE                                          GIS_Notes  \
# 0      AMME  PRELIMINARY - Data has not completed the entir...
# 1      CEBE  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 2      LIBI  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 3      CAVO  Lands - http://landsnet.nps.gov/tractsnet/docu...
# 4      FOBO  Lands - http://landsnet.nps.gov/tractsnet/docu...
#
#                                            UNIT_NAME   DATE_EDIT STATE REGION  \
# 0                             American Memorial Park  2015-04-22    MP     PW
# 1  Cedar Creek and Belle Grove National Historica...  2005-04-07    VA     NE
# 2       Little Bighorn Battlefield National Monument  2005-02-23    MT     IM
# 3                  Capulin Volcano National Monument  2004-07-22    NM     IM
# 4                  Fort Bowie National Historic Site  2004-05-12    AZ     IM
#
#    GNIS_ID                 UNIT_TYPE CREATED_BY  \
# 0  1879026                      Park      Lands
# ...

# %%
NP = NP_geo[NP_geo['UNIT_TYPE'] == 'National Park'].reset_index()
NP_list = NP[['UNIT_CODE', 'UNIT_NAME', 'STATE', 'UNIT_TYPE', 'Shape_Area', 'geometry']]
NP_list
# Out:
#    UNIT_CODE                            UNIT_NAME STATE      UNIT_TYPE  \
# 0       DRTO           Dry Tortugas National Park    FL  National Park
# 1       BRCA           Bryce Canyon National Park    UT  National Park
# 2       YELL            Yellowstone National Park    WY  National Park
# 3       SEQU                Sequoia National Park    CA  National Park
# 4       MACA           Mammoth Cave National Park    KY  National Park
# ..       ...                                  ...   ...            ...
# 57      SAGU                Saguaro National Park    AZ  National Park
# 58      HAVO      Hawai'i Volcanoes National Park    HI  National Park
# 59      SHEN             Shenandoah National Park    VA  National Park
# 60      GRSM  Great Smoky Mountains National Park    NC  National Park
# 61      ACAD                 Acadia National Park    ME  National Park
#
#     Shape_Area                                           geometry
# ...

# %%
# NP_list.plot()
# Out:
# <AxesSubplot:>

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.google.com/travel/flights/search?tfs=CBwQAhojagwIAhIIL20vMGRjbGcSCjIwMjEtMTItMTJyBwgBEgNTRk9wAYIBCwj___________8BQAFIAZgBAg&tfu=EgYIAhAAGAA&hl=en&gl=us&curr=USD'
r = requests.get(url)
# print(r.content)

# %%
soup = BeautifulSoup(r.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <base href="https://www.google.com/"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="vzI4y-3iMecKTIHcKK5ZK6Ox4-K5SAJWV5tqgCxry20" name="google-site-verification"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="Travel" name="application-name"/>
#   <meta content="Travel" name="apple-mobile-web-app-title"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="no" name="msapplication-tap-highlight"/>
#   <link href="//lh3.googleusercontent.com" rel="preconnect"/>
#   <link href="//lh4.googleusercontent.com" rel="preconnect"/>
# ...

# %%
#id_0_12 > span > span > div > div > div.content-cell--fare > span > span:nth-child(2) > span.content-cell--fare_usd
selector = "#yDmH0d > c-wiz.zQTmif.SSPGKf > div > div.lteUWc > div > c-wiz > div > c-wiz > c-wiz > div.WZwUvb.EA71Tc > div.N8AcTe > div > div.yDBH5d > div.irPLyc.NppLad > div > div:nth-child(2) > div > div.VKb8lb.H4aYKc > div:nth-child(1) > div > div.KC3CM > div.mxvQLc.ceis6c.uj4xv.uVdL1c.A8qKrc > div.OgQvJf.nKlB3b > div.U3gSDe > div.BVAVmf.I11szd.POX3ye > div.YMlIz.FpEdX.jLMuyc > span"
first_price = soup.select(selector)

# %%
len(first_price)
# first_price[0]
# Out:
# 0
